# %% [markdown]
# ##Clone from fp-dataset-artifacts

# %%
# !git clone https://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@github.com/henryleo13/fp-dataset-artifacts.git
# Out:
# Cloning into 'fp-dataset-artifacts'...
# remote: Enumerating objects: 120, done.
# remote: Total 120 (delta 0), reused 0 (delta 0), pack-reused 120
# Receiving objects: 100% (120/120), 38.64 KiB | 4.83 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# %cd fp-dataset-artifacts
# Out:
# /content/fp-dataset-artifacts

# %% [markdown]
# ##Install requirements

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Download Evaluation dataset

# %%
# Downloads multinli dataset

# !wget https://cims.nyu.edu/~sbowman/multinli/multinli_1.0.zip
# !unzip multinli_1.0.zip

# Downloads NLI_Break dataset

# Download Hans dataset
# !wget https://github.com/tommccoy1/hans/blob/master/heuristics_evaluation_set.jsonl
# Out:
# --2023-12-02 23:54:42--  https://cims.nyu.edu/~sbowman/multinli/multinli_1.0.zip
# Resolving cims.nyu.edu (cims.nyu.edu)... 216.165.22.202
# Connecting to cims.nyu.edu (cims.nyu.edu)|216.165.22.202|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226850426 (216M) [application/zip]
# Saving to: ‘multinli_1.0.zip’
#
# multinli_1.0.zip    100%[===================>] 216.34M  28.4MB/s    in 9.6s
#
# 2023-12-02 23:54:52 (22.6 MB/s) - ‘multinli_1.0.zip’ saved [226850426/226850426]
#
# Archive:  multinli_1.0.zip
#    creating: multinli_1.0/
#   inflating: multinli_1.0/multinli_1.0_dev_mismatched.jsonl
#   inflating: multinli_1.0/paper.pdf
#    creating: __MACOSX/
#    creating: __MACOSX/multinli_1.0/
#   inflating: __MACOSX/multinli_1.0/._paper.pdf
#   inflating: multinli_1.0/.DS_Store
#   inflating: __MACOSX/multinli_1.0/._.DS_Store
#   inflating: multinli_1.0/multinli_1.0_train.jsonl
#   inflating: multinli_1.0/multinli_1.0_dev_mismatched.txt
# ...

# %% [markdown]
# ## Download Evaluation Datasets

# %%
# Create the 'datasets/' subdirectory
# !mkdir datasets

# Download the Multinli dataset zip file
# !wget https://cims.nyu.edu/~sbowman/multinli/multinli_1.0.zip -P datasets/

# Unzip the contents to the 'datasets/' subdirectory
# !unzip datasets/multinli_1.0.zip -d datasets/

# Optional: Remove the zip file if you don't need it anymore
# !rm datasets/multinli_1.0.zip

# Hans Dataset
#!wget https://github.com/tommccoy1/hans/blob/master/heuristics_evaluation_set.jsonl -P datasets/
# Out:
# --2023-12-05 16:01:25--  https://cims.nyu.edu/~sbowman/multinli/multinli_1.0.zip
# Resolving cims.nyu.edu (cims.nyu.edu)... 216.165.22.202
# Connecting to cims.nyu.edu (cims.nyu.edu)|216.165.22.202|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226850426 (216M) [application/zip]
# Saving to: ‘datasets/multinli_1.0.zip’
#
# multinli_1.0.zip    100%[===================>] 216.34M  29.9MB/s    in 7.6s
#
# 2023-12-05 16:01:34 (28.4 MB/s) - ‘datasets/multinli_1.0.zip’ saved [226850426/226850426]
#
# Archive:  datasets/multinli_1.0.zip
#    creating: datasets/multinli_1.0/
#   inflating: datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl
#   inflating: datasets/multinli_1.0/paper.pdf
#    creating: datasets/__MACOSX/
#    creating: datasets/__MACOSX/multinli_1.0/
#   inflating: datasets/__MACOSX/multinli_1.0/._paper.pdf
#   inflating: datasets/multinli_1.0/.DS_Store
#   inflating: datasets/__MACOSX/multinli_1.0/._.DS_Store
# ...

# %% [markdown]
# Have to manually upload HANS set

# %% [markdown]
# ## Train/Save/Load model

# %%
# !python3 run.py --do_train --num_train_epochs 10 --task nli --per_device_train_batch_size 256 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./trained_model/mnli10/
# Out:
# 2023-11-27 21:07:09.426666: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 21:07:09.426724: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 21:07:09.426765: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 21:07:11.006446: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r mnli_model_10e.zip trained_model/mnli10/*
# Out:
#   adding: trained_model/mnli10/checkpoint-1000/ (stored 0%)
#   adding: trained_model/mnli10/checkpoint-1000/config.json (deflated 54%)
#   adding: trained_model/mnli10/checkpoint-1000/optimizer.pt (deflated 12%)
#   adding: trained_model/mnli10/checkpoint-1000/rng_state.pth (deflated 25%)
#   adding: trained_model/mnli10/checkpoint-1000/scheduler.pt (deflated 55%)
#   adding: trained_model/mnli10/checkpoint-1000/tokenizer.json (deflated 71%)
#   adding: trained_model/mnli10/checkpoint-1000/vocab.txt (deflated 53%)
#   adding: trained_model/mnli10/checkpoint-1000/training_args.bin (deflated 51%)
#   adding: trained_model/mnli10/checkpoint-1000/model.safetensors (deflated 7%)
#   adding: trained_model/mnli10/checkpoint-1000/special_tokens_map.json (deflated 42%)
#   adding: trained_model/mnli10/checkpoint-1000/trainer_state.json (deflated 54%)
#   adding: trained_model/mnli10/checkpoint-1000/tokenizer_config.json (deflated 76%)
# ...

# %% [markdown]
# Upload a zip file of model and then move to fp-dataset-artifacts folder and then run command below

# %%
# !unzip mnli10_only.zip
#!unzip student_model_3epoch
# Out:
# Archive:  mnli10_only.zip
#    creating: mnli10/3e/
#   inflating: mnli10/3e/config.json
#   inflating: mnli10/3e/model.safetensors
#   inflating: mnli10/3e/optimizer.pt
#   inflating: mnli10/3e/rng_state.pth
#   inflating: mnli10/3e/scheduler.pt
#   inflating: mnli10/3e/special_tokens_map.json
#   inflating: mnli10/3e/tokenizer.json
#   inflating: mnli10/3e/tokenizer_config.json
#   inflating: mnli10/3e/trainer_state.json
#   inflating: mnli10/3e/training_args.bin
#   inflating: mnli10/3e/vocab.txt
#   inflating: mnli10/config.json
#   inflating: mnli10/model.safetensors
#    creating: mnli10/runs/
#    creating: mnli10/runs/Nov27_21-07-11_86ab0c42b32c/
#   inflating: mnli10/runs/Nov27_21-07-11_86ab0c42b32c/events.out.tfevents.1701119310.86ab0c42b32c.126365.0
#   inflating: mnli10/special_tokens_map.json
#   inflating: mnli10/tokenizer.json
#   inflating: mnli10/tokenizer_config.json
#   inflating: mnli10/training_args.bin
#   inflating: mnli10/vocab.txt

# %% [markdown]
# ## Evaluate Model

# %%
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --model ./trained_model/mnli/checkpoint-18000/ --output_dir ./eval_output/mnli_on_train/
# !zip -r mnli_eval_train.zip eval_output/mnli_on_train/*
# Out:
# 2023-11-16 20:42:27.162194: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 20:42:27.162254: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 20:42:27.162287: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 20:42:28.852543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# Map: 100% 392702/392702 [00:35<00:00, 10953.78 examples/s]
# Map (num_proc=2): 100% 392702/392702 [01:28<00:00, 4417.34 examples/s]
# ...

# %%
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./trained_model/mnli/checkpoint-18000/ --output_dir ./eval_output/
# Out:
# 2023-11-16 20:35:38.288887: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 20:35:38.288949: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 20:35:38.288989: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 20:35:40.022219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 988.29it/s]
# Generating train split: 10000 examples [00:00, 59171.55 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./trained_model/mnli/checkpoint-18000/ --output_dir ./eval_output/
# Out:
# 2023-11-16 20:37:48.001345: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 20:37:48.001405: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 20:37:48.001448: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 20:37:49.720266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 914.39it/s]
# Generating train split: 10000 examples [00:00, 61527.03 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
#!python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./trained_model/mnli10/ --output_dir ./eval_output/mnli_10e_hans/
# !zip -r mnli_model_30e_evals.zip eval_output/a50/*
#!python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model/from_cp9000/checkpoint-7000/ --output_dir ./evals/student_on_hans_e5/
# Out:
# 2023-11-28 01:06:01.271643: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 01:06:01.271699: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 01:06:01.271748: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 01:06:03.100631: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# Map (num_proc=2): 100% 30000/30000 [00:04<00:00, 7201.35 examples/s]
# Trainer Type: MyTrainer
# ...

# %% [markdown]
# ## Train Biased on Synthetic MNLI Dataset

# %%
# !python3 run.py --do_train --do_eval --task nli --train_size 10000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_10k_syn/

# !python3 run.py --do_train --do_eval --task nli --train_size 5000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_5k_syn/

# !python3 run.py --do_train --do_eval --task nli --train_size 15000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_15k_syn/

# !python3 run.py --do_train --do_eval --task nli --train_size 20000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_20k_syn/

# !python3 run.py --do_train --do_eval --task nli --train_size 2000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_2k_syn/

#!python3 run.py --do_train --do_eval --task nli --train_size 30000 --eval_size 5000 --per_device_train_batch_size 128 --num_train_epochs 10 --synthetic_data True --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_synthetic2/biased_model_30k_syn/
# Out:
# Streaming output truncated to the last 5000 lines.
#  77% 481/625 [00:07<00:02, 51.72it/s]
#  78% 487/625 [00:07<00:02, 51.45it/s]
#  79% 493/625 [00:07<00:02, 50.68it/s]
#  80% 499/625 [00:07<00:02, 49.44it/s]
#  81% 504/625 [00:08<00:02, 49.23it/s]
#  81% 509/625 [00:08<00:02, 46.38it/s]
#  82% 514/625 [00:08<00:02, 45.81it/s]
#  83% 519/625 [00:08<00:02, 46.52it/s]
#  84% 524/625 [00:08<00:02, 46.61it/s]
#  85% 530/625 [00:08<00:01, 47.74it/s]
#  86% 535/625 [00:08<00:01, 47.74it/s]
#  86% 540/625 [00:08<00:01, 47.58it/s]
#  87% 545/625 [00:08<00:01, 47.53it/s]
#  88% 550/625 [00:09<00:01, 47.30it/s]
#  89% 555/625 [00:09<00:01, 45.87it/s]
#  90% 560/625 [00:09<00:01, 46.11it/s]
#  90% 565/625 [00:09<00:01, 43.05it/s]
#  91% 570/625 [00:09<00:01, 44.35it/s]
#  92% 575/625 [00:09<00:01, 45.67it/s]
#  93% 580/625 [00:09<00:00, 46.18it/s]
#  94% 585/625 [00:09<00:00, 46.74it/s]
#  94% 590/625 [00:09<00:00, 46.19it/s]
#  95% 595/625 [00:09<00:00, 46.67it/s]
# ...

# %%
# !zip -r biased_model_syn.zip biased_synthetic2/*
#!zip -r biased_model_15k_syn.zip biased_synthetic2/biased_model_15k_syn/model/*
#!zip -r biased_model_20k_syn.zip biased_synthetic2/biased_model_20k_syn/model/*
#!zip -r biased_model_2k_syn.zip biased_synthetic2/biased_model_2k_syn/model/*
#!zip -r biased_model_5k_syn.zip biased_synthetic2/biased_model_5k_syn/model/*
# Out:
#   adding: biased_synthetic2/biased_model_10k_syn/ (stored 0%)
#   adding: biased_synthetic2/biased_model_10k_syn/training_args.bin (deflated 51%)
#   adding: biased_synthetic2/biased_model_10k_syn/eval_predictions.jsonl (deflated 65%)
#   adding: biased_synthetic2/biased_model_10k_syn/model.safetensors (deflated 7%)
#   adding: biased_synthetic2/biased_model_10k_syn/config.json (deflated 54%)
#   adding: biased_synthetic2/biased_model_10k_syn/runs/ (stored 0%)
#   adding: biased_synthetic2/biased_model_10k_syn/runs/Dec03_00-09-10_f90710292e01/ (stored 0%)
#   adding: biased_synthetic2/biased_model_10k_syn/runs/Dec03_00-09-10_f90710292e01/events.out.tfevents.1701562163.f90710292e01.5617.0 (deflated 70%)
#   adding: biased_synthetic2/biased_model_10k_syn/runs/Dec03_00-09-10_f90710292e01/events.out.tfevents.1701563766.f90710292e01.5617.1 (deflated 46%)
#   adding: biased_synthetic2/biased_model_10k_syn/runs/.ipynb_checkpoints/ (stored 0%)
# ...

# %%
# !rm -r /biased_synthetic/biased_model_10k_syn/checkpoint-117
# Out:
# rm: cannot remove '/biased_synthetic/biased_model_10k_syn/checkpoint-117': No such file or directory

# %% [markdown]
# ## Train Biased Model

# %%
# !python3 run.py --do_train --do_eval --task nli --train_size 10000 --eval_size 2000 --per_device_train_batch_size 128 --num_train_epochs 4 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_10k_2e/

#!python3 run.py --do_train --do_eval --task nli --train_size 5000 --eval_size 1000 --per_device_train_batch_size 128 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_5k/

#!python3 run.py --do_train --do_eval --task nli --train_size 15000 --eval_size 3000 --per_device_train_batch_size 128 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_15k/

#!python3 run.py --do_train --do_eval --task nli --train_size 20000 --eval_size 4000 --per_device_train_batch_size 128 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_20k/

#!python3 run.py --do_train --do_eval --task nli --train_size 2000 --eval_size 400 --per_device_train_batch_size 128 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_2k/

#!python3 run.py --do_train --do_eval --task nli --train_size 30000 --eval_size 6000 --per_device_train_batch_size 128 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./biased_model_30k/
# Out:
# 2023-12-03 14:12:29.880695: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 14:12:29.880762: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 14:12:29.880814: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 14:12:31.561316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1106.68it/s]
# Generating train split: 392702 examples [00:04, 97124.89 examples/s]
# config.json: 100% 665/665 [00:00<00:00, 3.91MB/s]
# ...

# %%
# !zip -r biased_model_10k_2e.zip biased_model_10k_2e/*

#!zip -r biased_model_5k.zip biased_model_5k/*

#!zip -r biased_model_15k.zip biased_model_15k/*

#!zip -r biased_model_20k.zip biased_model_20k/*

#!zip -r biased_model_2k.zip biased_model_2k/*

#!zip -r biased_model_30k.zip biased_model_30k/*
# Out:
#   adding: biased_model_10k_2e/2e/ (stored 0%)
#   adding: biased_model_10k_2e/2e/training_args.bin (deflated 51%)
#   adding: biased_model_10k_2e/2e/model.safetensors (deflated 7%)
#   adding: biased_model_10k_2e/2e/config.json (deflated 54%)
#   adding: biased_model_10k_2e/2e/rng_state.pth (deflated 25%)
#   adding: biased_model_10k_2e/2e/tokenizer_config.json (deflated 76%)
#   adding: biased_model_10k_2e/2e/tokenizer.json (deflated 71%)
#   adding: biased_model_10k_2e/2e/optimizer.pt (deflated 20%)
#   adding: biased_model_10k_2e/2e/special_tokens_map.json (deflated 42%)
#   adding: biased_model_10k_2e/2e/scheduler.pt (deflated 56%)
#   adding: biased_model_10k_2e/2e/trainer_state.json (deflated 74%)
#   adding: biased_model_10k_2e/2e/vocab.txt (deflated 53%)
#   adding: biased_model_10k_2e/checkpoint-158/ (stored 0%)
#   adding: biased_model_10k_2e/checkpoint-158/training_args.bin (deflated 51%)
#   adding: biased_model_10k_2e/checkpoint-158/model.safetensors (deflated 7%)
# ...

# %% [markdown]
# ## Train Student Model

# %%
# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_5e_bias10k2e/ --biased_model ./biased_model_10k_2e/2e/
# !zip -r student_model_5e_bias10k2e.zip student_model_5e_bias10k2e/*
# !python3 run.py --do_train --task nli --model ./student_model_5e_bias10k2e/ --per_device_train_batch_size 256 --num_train_epochs 10 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_10e_bias10k2e/ --biased_model ./biased_model_10k_2e/2e/
# Out:
# 2023-12-03 14:27:44.327112: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 14:27:44.327170: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 14:27:44.327207: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 14:27:45.506755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r student_model_10e_bias10k2e.zip student_model_5e_bias10k2e/model/*
# Out:
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/ (stored 0%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/training_args.bin (deflated 51%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/model.safetensors (deflated 7%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/config.json (deflated 54%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/rng_state.pth (deflated 25%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/tokenizer_config.json (deflated 76%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/tokenizer.json (deflated 71%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/optimizer.pt (deflated 12%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/special_tokens_map.json (deflated 42%)
#   adding: student_model_5e_bias10k2e/model/checkpoint-4500/scheduler.pt (deflated 56%)
# ...

# %% [markdown]
# ## Evaluate Student Model

# %%
# Dev matched
#!python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_5e_bias10k2e/model/ --output_dir ./eval_output/student_model_10e_bias10k2e/dev_matched/
# Dev mismatched
#!python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_5e_bias10k2e/model/ --output_dir ./eval_output/student_model_10e_bias10k2e/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_5e_bias10k2e/model/ --output_dir ./eval_output/student_model_10e_bias10k2e/HANS/
# !zip -r student_model_10e_bias10k2e_evals.zip eval_output/student_model_10e_bias10k2e/*

# 3 Epoch Run
# Dev matched
#!python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/student_model_3e_bias10k2e/dev_matched/
# Dev mismatched
#!python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/student_model_3e_bias10k2e/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/student_model_3e_bias10k2e/HANS/
# !zip -r student_model_3e_bias10k2e_evals.zip eval_output/student_model_3e_bias10k2e/*
# Out:
# 2023-12-03 19:37:02.780525: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 19:37:02.780586: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 19:37:02.780624: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 19:37:04.027819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1331.10it/s]
# Generating train split: 30000 examples [00:00, 155261.40 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
# !zip -r student_model_3epoch.zip student_model/checkpoint-9000/*
# Out:
#   adding: student_model/checkpoint-9000/config.json (deflated 54%)
#   adding: student_model/checkpoint-9000/model.safetensors (deflated 7%)
#   adding: student_model/checkpoint-9000/optimizer.pt (deflated 12%)
#   adding: student_model/checkpoint-9000/rng_state.pth (deflated 25%)
#   adding: student_model/checkpoint-9000/scheduler.pt (deflated 56%)
#   adding: student_model/checkpoint-9000/special_tokens_map.json (deflated 42%)
#   adding: student_model/checkpoint-9000/tokenizer_config.json (deflated 76%)
#   adding: student_model/checkpoint-9000/tokenizer.json (deflated 71%)
#   adding: student_model/checkpoint-9000/trainer_state.json (deflated 75%)
#   adding: student_model/checkpoint-9000/training_args.bin (deflated 51%)
#   adding: student_model/checkpoint-9000/vocab.txt (deflated 53%)

# %% [markdown]
# ## Train Student Model with Annealing

# %%
# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 3 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_biased10k2e_annealed/a90/ --biased_model ./biased_model_10k_2e/2e/ --min_theta 0.9

# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 3 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_biased10k2e_annealed/a80/ --biased_model ./biased_model_10k_2e/2e/ --min_theta 0.8

# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 3 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_biased10k2e_annealed/a70/ --biased_model ./biased_model_10k_2e/2e/ --min_theta 0.7

# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 3 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_biased10k2e_annealed/a60/ --biased_model ./biased_model_10k_2e/2e/ --min_theta 0.6

# !python3 run.py --do_train --task nli --per_device_train_batch_size 256 --num_train_epochs 3 --dataset ./datasets/multinli_1.0/multinli_1.0_train.jsonl --output_dir ./student_model_biased10k2e_annealed/a50/ --biased_model ./biased_model_10k_2e/2e/ --min_theta 0.5
# Out:
# 2023-12-04 10:33:39.638048: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 10:33:39.638120: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 10:33:39.638165: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 10:33:40.784336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1090.00it/s]
# Generating train split: 392702 examples [00:04, 84975.99 examples/s]
# config.json: 100% 665/665 [00:00<00:00, 3.51MB/s]
# ...

# %% [markdown]
# ### Zip Models

# %%
# !zip -r student_model_biased10k2e_a90.zip student_model_biased10k2e_annealed/a90/model/*
# !zip -r student_model_biased10k2e_a80.zip student_model_biased10k2e_annealed/a80/model/*
# !zip -r student_model_biased10k2e_a70.zip student_model_biased10k2e_annealed/a70/model/*
# !zip -r student_model_biased10k2e_a60.zip student_model_biased10k2e_annealed/a60/model/*
# !zip -r student_model_biased10k2e_a50.zip student_model_biased10k2e_annealed/a50/model/*
# Out:
#   adding: student_model_biased10k2e_annealed/a90/model/config.json (deflated 54%)
#   adding: student_model_biased10k2e_annealed/a90/model/model.safetensors (deflated 7%)
#   adding: student_model_biased10k2e_annealed/a90/model/runs/ (stored 0%)
#   adding: student_model_biased10k2e_annealed/a90/model/runs/Dec04_10-33-41_24ba88807a8b/ (stored 0%)
#   adding: student_model_biased10k2e_annealed/a90/model/runs/Dec04_10-33-41_24ba88807a8b/events.out.tfevents.1701686151.24ba88807a8b.6920.0 (deflated 59%)
#   adding: student_model_biased10k2e_annealed/a90/model/special_tokens_map.json (deflated 42%)
#   adding: student_model_biased10k2e_annealed/a90/model/tokenizer_config.json (deflated 76%)
#   adding: student_model_biased10k2e_annealed/a90/model/tokenizer.json (deflated 71%)
#   adding: student_model_biased10k2e_annealed/a90/model/training_args.bin (deflated 51%)
#   adding: student_model_biased10k2e_annealed/a90/model/vocab.txt (deflated 53%)
# ...

# %% [markdown]
# ### Evaluate the student models

# %%
# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/control/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/control/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_5e_bias10k2e/model/3e/ --output_dir ./eval_output/control/HANS/

# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_biased10k2e_annealed/a90/model/ --output_dir ./eval_output/a90/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_biased10k2e_annealed/a90/model/ --output_dir ./eval_output/a90/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_biased10k2e_annealed/a90/model/ --output_dir ./eval_output/a90/HANS/
#!zip -r student_model_a90_evals.zip eval_output/a90/*

# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_biased10k2e_annealed/a80/model/ --output_dir ./eval_output/a80/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_biased10k2e_annealed/a80/model/ --output_dir ./eval_output/a80/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_biased10k2e_annealed/a80/model/ --output_dir ./eval_output/a80/HANS/
#!zip -r student_model_a80_evals.zip eval_output/a80/*

# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_biased10k2e_annealed/a70/model/ --output_dir ./eval_output/a70/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_biased10k2e_annealed/a70/model/ --output_dir ./eval_output/a70/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_biased10k2e_annealed/a70/model/ --output_dir ./eval_output/a70/HANS/
#!zip -r student_model_a70_evals.zip eval_output/a70/*

# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_biased10k2e_annealed/a60/model/ --output_dir ./eval_output/a60/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_biased10k2e_annealed/a60/model/ --output_dir ./eval_output/a60/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_biased10k2e_annealed/a60/model/ --output_dir ./eval_output/a60/HANS/
#!zip -r student_model_a60_evals.zip eval_output/a60/*

# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_biased10k2e_annealed/a50/model/ --output_dir ./eval_output/a50/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_biased10k2e_annealed/a50/model/ --output_dir ./eval_output/a50/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_biased10k2e_annealed/a50/model/ --output_dir ./eval_output/a50/HANS/
#!zip -r student_model_a50_evals.zip eval_output/a50/*

# !zip -r student_model_biased10k2e_annealed_evals.zip eval_output/*
# Out:
# 2023-12-04 18:28:32.410578: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 18:28:32.410641: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 18:28:32.410684: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 18:28:33.748349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# Trainer Type: MyTrainer
# ...

# %%
#Base model 10epoch
# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./mnli10/ --output_dir ./eval_output/base_10e/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./mnli10/ --output_dir ./eval_output/base_10e/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./mnli10/ --output_dir ./eval_output/base_10e/HANS/
# !zip -r base_10e_evals.zip eval_output/base_10e/*

#Debias Model bias15k10e 3 Epochs
# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_15k/3e/ --output_dir ./eval_output/bias15k10e/3e/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_15k/3e/ --output_dir ./eval_output/bias15k10e/3e/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_15k/3e/ --output_dir ./eval_output/bias15k10e/3e/HANS/

#Debias Model bias15k10e 10 Epochs
# Dev matched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_matched.jsonl --model ./student_model_15k/ --output_dir ./eval_output/bias15k10e/10e/dev_matched/
# Dev mismatched
# !python3 run.py --do_eval --task nli --dataset ./datasets/multinli_1.0/multinli_1.0_dev_mismatched.jsonl --model ./student_model_15k/ --output_dir ./eval_output/bias15k10e/10e/dev_mismatched/
# HANS
# !python3 run.py --do_eval --task nli --dataset ./datasets/heuristics_evaluation_set.jsonl --model ./student_model_15k/ --output_dir ./eval_output/bias15k10e/10e/HANS/

# !zip -r student_bias15k10e_evals.zip eval_output/bias15k10e/*
# Out:
# 2023-12-05 16:12:14.685308: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 16:12:14.685379: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 16:12:14.685433: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 16:12:16.287800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1074.91it/s]
# Generating train split: 10000 examples [00:00, 50654.74 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...
